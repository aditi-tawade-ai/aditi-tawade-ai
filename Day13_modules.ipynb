# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-tawade-ai/aditi-tawade-ai/blob/main/Day13_modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#3. reduce(function,iterable)--.it is used to convert collection into a single value/object

#reduce is present in funtools module

from functools import reduce
k=[1,2,3,4,5,6]
reduce(lambda x,y:x*y,k)

#in reduce we do not typecaste like we did in map,filter
# Out:
# 720

# %%
from functools import reduce
k=[1,2,3,4,5,6]
reduce(lambda x,y:x*y,k)
# Out:
# 720

# %%
k=[1,2,3,4,5,6]
reduce(lambda x,y:x-y,k)
# Out:
# -19

# %% [markdown]
# # **Modules in Python**

# %%
# a file profile with .py extension is a module
#means any python file is a module
#interpreted -line by line

# %%
#we have 2 types of modules
#1. built in module--. modules present in python itself
#to use any module u need import keyword
#syntax:import module_name

# %%
#we will import math module
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(7)
# Out:
# 5040

# %%
#module aliasing-->give a short or nick name
# it is required when we have bigger module names n we want short name to refer
import math as m

# %%
m.sqrt(625)
# Out:
# 25.0

# %%
m.pow(15,3)
# Out:
# 3375.0

# %%
# to import only specific and required thing we need to go with
#from module_name import member
from math import pi,factorial

# %%
pi
# Out:
# 3.141592653589793

# %%
factorial(6)
# Out:
# 720

# %%
# member aliasing - assign a short name to member of the module
from math import factorial as f,sqrt as s

# %%
f(4)
# Out:
# 24

# %%
s(25)
# Out:
# 5.0

# %%
#to import all numbers in 1 go use*approach
from math import*

# %%
e
# Out:
# 2.718281828459045

# %%
sqrt(125)
# Out:
# 11.180339887498949

# %%
f(8)
# Out:
# 40320

# %%
#Assignment:
#os,io,sys,array,collection,itertools,csv,counters

# %%
#create a file bank_info.py
#add below contents

name='gayatri'

place = 'Mumbai'

def account(name,place):
  print('Hi',name,'welcome to SBI branch',place)

# %%
from bank_info import name,place,account

# %%
name
# Out:
# 'gayatri'

# %%
place
# Out:
# 'Mumbai'

# %%
account(name,place)
# Out:
# Hi gayatri welcome to SBI branch Mumbai

# %%
import os
