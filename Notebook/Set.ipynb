# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-tawade-ai/aditi-tawade-ai/blob/main/Notebook/Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Set & dictionary**

# %%
#both are mutable data types
#set {at least one element inside}

# %%
s={}
type(s)
# Out:
# dict

# %%
s1={1.3}
type(s1)
# Out:
# set

# %%
#features of set
#duplicates are not allowed
p={1,2,3,4,1,1,1,2,2,2,3,3,3,4,4,}
p
# Out:
# {1, 2, 3, 4}

# %%
p={1,290,3,4,1,'B',1,2,'A',2,3,3,'python',4,4,}
p
# Out:
# {1, 2, 290, 3, 4, 'A', 'B', 'python'}

# %%
b={1,5,6,8,10,2,'233',3,9,4,7}
b
# Out:
# {1, 10, 2, '233', 3, 4, 5, 6, 7, 8, 9}

# %%
#dosent preserves sequential order
#when we use one type of pure data it gives sequential order but not necessarily
#background data structure of a set is a hash table
#and hash table dosent support indexing and slicing so no sequential order

# %%
#set is mutable
b
# Out:
# {1, 10, 2, '233', 3, 4, 5, 6, 7, 8, 9}

# %%
#try to remove the members of set
b.pop()
# Out:
# 1

# %%
b
# Out:
# {10, 2, '233', 3, 4, 5, 6, 7, 8, 9}

# %%
b.pop('3')
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2508/4246779310.py in <cell line: 0>()
# ----> 1 b.pop('3')
#       2 b
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
b.pop()
b
# Out:
# {10, '233', 3, 4, 5, 6, 7, 8, 9}

# %%
b.pop()
b
# Out:
# {10, '233', 4, 5, 6, 7, 8, 9}

# %%
lot={1122,4523,8563,9736,1230}
winner=lot.pop()
winner
# Out:
# 1122

# %%
winner=lot.pop()
winner
# Out:
# 8563

# %%
lot
# Out:
# {1230, 4523, 9736}

# %%
print('original lot:',lot)
out=lot.pop()
print('element removed:',out,'current set:',lot)
# Out:
# original lot: {9736, 4523, 1230}
# element removed: 9736 current set: {4523, 1230}

# %%
#remove(value based)
p={1,2,3,4,5,6}
p
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
p.remove(4)
p
# Out:
# {1, 2, 3, 5, 6}

# %%
p.remove(3)
p
# Out:
# {1, 2, 5, 6}

# %%
#if we remove the element which is not present
p.remove(7)
p
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2508/1608158635.py in <cell line: 0>()
# ----> 1 p.remove(7)
#       2 p
#
# KeyError: 7

# %%
x={'A','B','C'}
x
# Out:
# {'A', 'B', 'C'}

# %%
#pop()
x.pop()#returns an element which it removes
# Out:
# 'A'

# %%
x
# Out:
# {'B', 'C'}

# %%
x.remove('A')#A is already removed so gives error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2508/2725322150.py in <cell line: 0>()
# ----> 1 x.remove('A')#A is already removes so gives error
#
# KeyError: 'A'

# %%
#does not returns the element which it removes directly removes it
x.remove('B')
x
# Out:
# set()

# %%
#Assignment :check all the elements of set
a={1,2,3,4,5}
