# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-tawade-ai/aditi-tawade-ai/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of python

# %% [markdown]
# #Different types of data types

# %%
a = 90
type(a)
# Out:
# int

# %%
type('.net')
# Out:
# str

# %%
type("c++")
# Out:
# str

# %%
#list
#syntax;[]
q=[1,2,3]
r=['A','B','C']
p=['X,''10','22.22','y']
type(p)
# Out:
# list

# %%
#tuple
#syntax()
t1=(1,2,3)
t2={'A','B','C'}
t3={'X','10',22.22,'Y'}
type(t1)
type(t2)
p.append(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3826/3042789205.py in <cell line: 0>()
#       6 type(t1)
#       7 type(t2)
# ----> 8 p.append(100)
#
# NameError: name 'p' is not defined

# %%
type(t3)
# Out:
# set

# %%
p.append(100)
p
# Out:
# ['X,10', '22.22', 'y', {'10', 22.22, 'X', 'Y'}, 100, 100, 100]

# %%
t1=(1,2,3)
t2=('A','B','C')
t3=('X',10,22.22,'Y')
type(t1)
# Out:
# tuple

# %%
#list is mutable can be changed syntax[]
# tuple is immutable cannot be changed syntax()
#to add or edit list we use append
p=[1,2,3]
q=('A','B','C')
p.append(100)
p
q.append(D)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3826/2886954655.py in <cell line: 0>()
#       6 p.append(100)
#       7 p
# ----> 8 q.append(D)
#
# AttributeError: 'tuple' object has no attribute 'append'
