# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-tawade-ai/aditi-tawade-ai/blob/main/Day4_list_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **List Methods**

# %%
#syntax[]
#features of list
#background data structure- Array
#it supports indexing and slicing
#it accepts all types of data
#we can create homo. and hetro list
#it preserves sequence order
#it allows duplicate records
#list is mutable in nature

#Q. Explain features of a list????

# %%
help(list.append)
# Out:
# Help on method_descriptor:
#
# append(self, object, /) unbound builtins.list method
#     Append object to the end of the list.

# %%
#how to create an empty list
a=[]
a
# Out:
# []

# %%
#2nd approach
b=list()
b
# Out:
# []

# %%
#assignment : how to create an empty string?

# %%
b=''
b
# Out:
# ''

# %%
#to add elements in empty list or normal list then use append (object) method
a=[1]
a.append(100)
a
# Out:
# [1, 100]

# %%
#operations in list are inplace/parmenant

# %%
#Assignment : try to add str, list,tuple,set ,dict

# %%
a=[100]
a
# Out:
# [100]

# %%
a=[100]
a.append('python')
a
# Out:
# [100, 'python']

# %%
a.append('1,2,3')
a
# Out:
# [100, 'python', '1,2,3']

# %%
data=(2,3,4)
data
# Out:
# (2, 3, 4)

# %%
#ADD ABOVE DATA IN A
a=[100]
a
data=(2,3,4)
a.append(data)
a
# Out:
# [100, (2, 3, 4)]

# %%
#add c++
a.append('c++')
a
# Out:
# [100, (2, 3, 4), 'c++']

# %%
b=[]
b
# Out:
# []

# %%
b.extend(data)
b
# Out:
# [2, 3, 4]

# %%
b.extend('C++')
b
# Out:
# [2, 3, 4, 'C', '+', '+']

# %%
#Q. append vs extend

# %%
#to remove elements from list we have 2 methods
#pop(default removes last element)

# %%
b
# Out:
# [2, 3, 4, 'C', '+', '+']

# %%
b.pop()
# Out:
# '+'

# %%
b
# Out:
# [2, 3, 4, 'C', '+']

# %%
#pop default removes last element

# %%
#pop(index)= we can remove element with its index
k=[1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
k.pop(2)
# Out:
# 3

# %%
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
help(k.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
#remove(value)
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
k.remove(6)

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
t=[1,2,3,4,1,1,1,4,5]
t.remove(1)

# %%
t
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5]

# %%
k=[1,2,3,4,5,6,7,8]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
k.pop(3)
# Out:
# 4

# %%
k
# Out:
# [1, 2, 3, 5, 6, 7, 8]

# %%
k.pop(4)
# Out:
# 6

# %%
k
# Out:
# [1, 2, 3, 5, 7, 8]

# %%
#remove all elements
k.clear()
k
# Out:
# []

# %%
t
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5]

# %%
#shallow copy-list is with same elements but ids are different

x=t.copy()
x
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5]

# %%
#add -1 in x
x.append(-1)
x
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5, -1]

# %%
t
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5]

# %%
id(t),id(x)
# Out:
# (133158541714368, 133158539354688)

# %%
y=x
y
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5, -1]

# %%
x
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5, -1]

# %%
#in above case we have 1 object with different names x,y hence
#if we change in either x/y changes will get reflected in both the list
x.append(100)
x
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5, -1, 100]

# %%
y
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5, -1, 100]

# %%
id(x),id(y)
# Out:
# (133158539354688, 133158539354688)

# %%
y.extend([20,40])
y
# Out:
# [2, 3, 4, 1, 1, 1, 4, 5, -1, 100, 20, 40]

# %%
#assignment: can we add a tuple tp a list using extend

# %% [markdown]
# # **Revision day 4**

# %%
#features of list
#syntax:[]
#the background data type of list is :Array
#it supports slicing and indexing
#it preserves sequential ordering
#it is mutable in nature
#we can create homo and hetro list
#it allows all types of data
#it allows duplicate records

# %% [markdown]
# **Methods of list**

# %%
#append - adds element at last
a=['1,2,3,4,5,6']
a.append(100)
a
# Out:
# ['1,2,3,4,5,6', 100]

# %%
a.append('Python')
a
# Out:
# ['1,2,3,4,5,6', 100, 'Python']

# %%
#extend - seperates the elements and adds at last
b=['aditi']
b.extend('tawade')
b
# Out:
# ['aditi', 't', 'a', 'w', 'a', 'd', 'e']

# %%
b.extend('20,30,40')
b
# Out:
# ['aditi', 't', 'a', 'w', 'a', 'd', 'e', '2', '0', ',', '3', '0', ',', '4', '0']

# %%
# to remove elements we have 2 methods
# 1. pop()          2. remove()

# %%
#pop method- removes elements as per the indexing
a
# Out:
# ['1,2,3,4,5,6', 100, 'Python']

# %%
a.pop() - #no index specified removes last element
a
# Out:
# ['1,2,3,4,5,6', 100]

# %%
a=['1','2','3','4','5','6']
a.pop(3)
a
# Out:
# ['1', '2', '3', '5', '6']

# %%
a.append(100)
a
# Out:
# ['1', '2', '3', '5', '6', 100]

# %%
a.pop(5)
a
# Out:
# ['1', '2', '3', '5', '6']

# %%
#remove - it is used to remove specific value
a=['1','2','3','4','5','6']
a.remove('2')
a
# Out:
# ['1', '3', '4', '5', '6']

# %%
a.remove('5')
a
# Out:
# ['1', '3', '4']

# %%
b=['aditi','tawade']
b.remove('tawade')
b
# Out:
# ['aditi']

# %%
# Q. difference between append and extend
# append- adds element at last of the list
# extend - seperates and adds element at the last of list

# %%
# Q. difference between pop and remove
# pop- removes element based on indexing
# remove- removes specific value given from the list

# %%
#clear - vanishes all the elements from list
c=['aditi tawade']
c.clear()
c
# Out:
# []

# %%
# Copy is of 2 types
# 1. shallow copy         2. deep copy

# %%
#shallow copy - same elements in different identifiers but with different ids if x is modified y is the original one does not gets modified

# %%
x=['python']
y=x.copy()
y
# Out:
# ['python']

# %%
y.append(100)
y
# Out:
# ['python', 100]

# %%
x
# Out:
# ['python']

# %%
id('x'), id('y')
# Out:
# (11709056, 11709104)

# %%
# deep copy - different identifiers with same elements and same id's

# %%
x
# Out:
# ['python']

# %%
x=['python']
z=x
z
# Out:
# ['python']

# %%
id(x),id(z)
# Out:
# (139625453000640, 139625453000640)

# %%
x.append('is nice')
x
# Out:
# ['python', 'is nice']

# %%
z
# Out:
# ['python', 'is nice']
