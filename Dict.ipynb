# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-tawade-ai/aditi-tawade-ai/blob/main/Dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dictionary**

# %%
a={}#empty dict
type(a)
# Out:
# dict

# %%
#set vs dict
#set is a collection of objects seperated by commas
#dict is a collection of key:value pairs

# %%
b={1:100,2:200,3:300}#syntax of dict
b
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
type(b)
# Out:
# dict

# %%
c={'name':'python','age':'22',2:22.2}
c
# Out:
# {'name': 'python', 'age': '22', 2: 22.2}

# %%
#features of dict
#duplicate keys are not allowed
g={1:10,1:1000,1:'java'}
g
# Out:
# {1: 'java'}

# %%
#rule- if we have multiple values with same key present in the dict then it takes last recent pair
#in above case 1:'java' is last key value pair
#iterable:collection of more than element

# %%
#in set we cannot give /add Mutable elements
#in dict we cannot give mutable object as key

# %%
u={1:100,(2,4):200,3:300} # (2,4)- tuple
u
# Out:
# {1: 100, (2, 4): 200, 3: 300}

# %%
u={1:100,[2,4]:200,3:300}   #list not allowed
u
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7117/3848010725.py in <cell line: 0>()
# ----> 1 u={1:100,[2,4]:200,3:300}
#       2 u
#
# TypeError: unhashable type: 'list'

# %%
#duplicates are allowed but not duplicate keys
u={1:100,2:200,3:300}
u
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
t={'aditi':'python','pranav':'python'}
t
# Out:
# {'aditi': 'python', 'pranav': 'python'}

# %%
a=()
type(a)
# Out:
# tuple

# %%
# methods of dict
# dict is mutable

# %%
# create a empty dict
x={}
x
# Out:
# {}

# %%
# add pair use update(dict)
x.update({1:10,2:20})

# %%
x
# Out:
# {1: 10, 2: 20}

# %%
# we can also use update to update already existing value of concerned key
x.update({2:'sql'})
x
# Out:
# {1: 10, 2: 'sql'}

# %%
 #we can also use setdefault method
help(x.setdefault)
# Out:
# Help on built-in function setdefault:
#
# setdefault(key, default=None, /) method of builtins.dict instance
#     Insert key with a value of default if key is not in the dictionary.
#
#     Return the value for key if key is in the dictionary, else default.

# %%
x.setdefault(4)#for key 4 it will add none as value 4: none
x
# Out:
# {1: 10, 2: 'sql', 4: None}

# %%
data={'name':'aditi'}
data.setdefault('age')
data
# Out:
# {'name': 'aditi', 'age': None}

# %%
data
# Out:
# {'name': 'aditi', 'age': None}

# %%
data={'name':'aditi'}
age=21
data.setdefault('age',age)
data
# Out:
# {'name': 'aditi', 'age': 21}

# %%
#insted of none we want another value
x.setdefault(5,'ABC')
x
# Out:
# {1: 10, 2: 'sql', 4: None, 5: 'ABC'}

# %%
# if key is already present n we try to give a new value or if we keep it empty
x.setdefault(5) # if key already exists in dict then setdefault returns its value, it wont update it to none
# Out:
# {1: 10, 2: 'sql', 4: None, 5: 'ABC'}

# %%
#to fetch keys only
x.keys()
# Out:
# dict_keys([1, 2, 4, 5])

# %%
#to fetch values only
x.values()
# Out:
# dict_values([10, 'sql', None, 'ABC'])

# %%
# to fetch both(key: values)
x.items()
# Out:
# dict_items([(1, 10), (2, 'sql'), (4, None), (5, 'ABC')])

# %%
#assignment to check remaining methods of dict

# %%
a={1:100,2:200,3:300,4:400,5:500}
type(a)
# Out:
# dict

# %%
#clears entire dict
a.clear()
a
# Out:
# {}

# %%
#deep copy
a={1:100,2:200,3:300,4:400,5:500}
b= a.copy()
b
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
from copy import deepcopy
a={1:100,2:200,3:300,4:400,5:500}
c=a
c
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
a={1:100,2:200,3:300,4:400,5:500,6:600}
c=a  #shallow copy changes are updated in both variables
c
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500, 6: 600}

# %%
a={1:100,2:200,3:300,4:400,5:500,6:600}
c=a
a==c
# Out:
# True

# %%
#pop
a.pop(1)
# Out:
# 100

# %%
a
# Out:
# {2: 200, 3: 300, 4: 400, 5: 500, 6: 600}

# %%
a.pop(3)
a
# Out:
# {1: 100, 2: 200, 4: 400, 5: 500}

# %%
a
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
#update adds elements in dict irrespective of intexing
a.update({1:100})
a
# Out:
# {2: 200, 4: 400, 5: 500, 6: 600, 1: 100}

# %%
#setdefault adds just the missing elements
a.setdefault(8,'800')
a
# Out:
# {2: 200, 4: 400, 5: 500, 6: 600, 1: 100, 7: None, 8: '800'}

# %%
#fromkeys used to create new dict with sequence of keys
keys=['name','age','city']

d= dict.fromkeys(keys)
d['name']=input('Enter your name:')
d['age']=int(input('Enter your age:'))
d['city']=input('Enter city u live:')
d
# Out:
# Enter your name:aditi
# Enter your age:22
# Enter city u live:kolhapur
# {'name': 'aditi', 'age': 22, 'city': 'kolhapur'}

# %%
d.setdefault('name','aditi') #here nothing changes becoz already none is stored in name
d
# Out:
# {'name': 'Aditi', 'age': 21, 'city': 'kolhapur'}

# %%
#items= gives all the elements of dict
a={1:100,2:200,3:300,4:400,5:500,6:600}
a.items()
# Out:
# dict_items([(1, 100), (2, 200), (3, 300), (4, 400), (5, 500), (6, 600)])

# %%
#keys - only key nums
a={1:100,2:200,3:300,4:400,5:500,6:600}
a.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5, 6])

# %%
#value - values in keyys
a.values()
# Out:
# dict_values([100, 200, 300, 400, 500, 600])

# %%
#pop item- removes the last (key,value)pair from pair and returns value in tuple
a.popitem()
# Out:
# (6, 600)

# %%
a
# Out:
# {1: 100, 2: 200, 4: 400, 5: 500}

# %%
a={1:100,2:200,3:300,4:400,5:500,6:600}
a.popitem()
# Out:
# (6, 600)

# %%
a.popitem()
# Out:
# (6, 600)

# %%
a
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
a.popitem()
# Out:
# (5, 500)

# %%
a
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
keys={1,2,3,4,5}
d=dict.fromkeys(keys)
d[1]=100
d[2]=200
d[3]=300
d[4]=400
d[5]=500
d
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
#get- is used to get the value of the specific key we want
d.get(3)
# Out:
# 300

# %%
d.get(1)
# Out:
# 100

# %%
a={1:100,2:200,3:300,4:400}
a.setdefault(5,500)
# Out:
# 500

# %%
a
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
a={'name':'aditi','age':22}
a.setdefault('city','pune')
a
# Out:
# {'name': 'aditi', 'age': 22, 'city': 'pune'}

# %%
data={'name','age','city'}
d=dict.fromkeys(data)
d['name']='adi'
d['age']=22
d['city']='pune'
d
# Out:
# {'name': 'adi', 'age': 22, 'city': 'pune'}
